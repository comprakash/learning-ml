# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales  salary
# 0                          0    sales     low
# 1                          0    sales  medium
# 2                          0    sales  medium
# 3                          0    sales     low
# 4                          0    sales     low
# ...                      ...      ...     ...
# 14994                      0  support     low
# 14995                      0  support     low
# 14996                      0  support     low
# 14997                      0  support     low
# 14998                      0  support     low
#
# [14999 rows x 10 columns]

# %%
hr_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
hr_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
hr_data.sample(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 877                  0.49             0.63               6
# 43                   0.10             0.80               7
# 4939                 0.69             0.59               3
# 6851                 0.48             0.56               3
# 14150                0.92             0.70               3
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 877                     265                   3              0     1
# 43                      281                   4              0     1
# 4939                    233                   3              0     0
# 6851                    229                   3              0     0
# 14150                   129                   3              0     0
#
#        promotion_last_5years       sales  salary
# 877                        0   technical     low
# 43                         0   technical     low
# 4939                       0     support  medium
# 6851                       0   technical     low
# 14150                      1  management    high

# %%
cat_hr_data = hr_data.select_dtypes(include=['object'])

# %%
cat_hr_data.sales.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_data.rename(columns={'sales':'department'}, inplace=True)

# %%
hr_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
    hr_data.salary.value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
hr_data.department.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
hr_data.groupby('department').satisfaction_level.mean()
# Out:
# department
# IT             0.618142
# RandD          0.619822
# accounting     0.582151
# hr             0.598809
# management     0.621349
# marketing      0.618601
# product_mng    0.619634
# sales          0.614447
# support        0.618300
# technical      0.607897
# Name: satisfaction_level, dtype: float64

# %%
hr_data.groupby(['number_project', 'left']).satisfaction_level.mean()
# Out:
# number_project  left
# 2               0       0.604397
#                 1       0.412948
# 3               0       0.689618
#                 1       0.579861
# 4               0       0.689181
#                 1       0.752689
# 5               0       0.657971
#                 1       0.752337
# 6               0       0.456570
#                 1       0.128366
# 7               1       0.118711
# Name: satisfaction_level, dtype: float64

# %%
hr_data.groupby(['number_project', 'left']).satisfaction_level.count()
# Out:
# number_project  left
# 2               0        821
#                 1       1567
# 3               0       3983
#                 1         72
# 4               0       3956
#                 1        409
# 5               0       2149
#                 1        612
# 6               0        519
#                 1        655
# 7               1        256
# Name: satisfaction_level, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=hr_data.satisfaction_level, y=hr_data.average_montly_hours, c=hr_data.left, s=5, alpha=0.5)
plt.colorbar()
plt.xlabel('satisfaction_level')
plt.ylabel('average_monthly_hours')
# Out:
# Text(0, 0.5, 'average_monthly_hours')
