# %%
import pandas as pd
import numpy as np

# %%
covid19_confirmed = pd.read_csv('./../data/time_series_covid19_confirmed_global.csv')

# %%
covid19_confirmed.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/20/20  3/21/20  3/22/20  3/23/20  \
# 0        0        0        0  ...       24       24       40       40
# 1        0        0        0  ...       70       76       89      104
# 2        0        0        0  ...       90      139      201      230
# 3        0        0        0  ...       75       88      113      133
# 4        0        0        0  ...        1        2        2        3
#
#    3/24/20  3/25/20  3/26/20  3/27/20  3/28/20  3/29/20
# ...

# %%
covid19_confirmed.sample()
# Out:
#     Province/State Country/Region       Lat        Long  1/22/20  1/23/20  \
# 239            NaN           Laos  19.85627  102.495496        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/20/20  3/21/20  3/22/20  \
# 239        0        0        0        0  ...        0        0        0
#
#      3/23/20  3/24/20  3/25/20  3/26/20  3/27/20  3/28/20  3/29/20
# 239        0        2        3        6        6        8        8
#
# [1 rows x 72 columns]

# %%
covid19_confirmed.sample(10)
# Out:
#     Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 137            NaN          Italy  43.0000   12.0000        0        0
# 175            NaN         Norway  60.4720    8.4689        0        0
# 73        Shandong          China  36.3427  118.1498        2        6
# 14        Victoria      Australia -37.8136  144.9631        0        0
# 35         Alberta         Canada  53.9333 -116.5765        0        0
# 193            NaN        Senegal  14.4974  -14.4524        0        0
# 208            NaN       Tanzania  -6.3690   34.8888        0        0
# 227            NaN      Venezuela   6.4238  -66.5897        0        0
# 39   New Brunswick         Canada  46.5653  -66.4619        0        0
# 197            NaN       Slovakia  48.6690   19.6990        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/20/20  3/21/20  3/22/20  \
# 137        0        0        0        0  ...    47021    53578    59138
# ...

# %%
covid19_confirmed.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
#        '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
#        '3/27/20', '3/28/20', '3/29/20'],
#       dtype='object')

# %%
covid19_confirmed.groupby(['Country/Region']).sum()
# Out:
#                         Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan         33.0000   65.0000        0        0        0        0
# Albania             41.1533   20.1683        0        0        0        0
# Algeria             28.0339    1.6596        0        0        0        0
# Andorra             42.5063    1.5218        0        0        0        0
# Angola             -11.2027   17.8739        0        0        0        0
# ...                     ...       ...      ...      ...      ...      ...
# Venezuela            6.4238  -66.5897        0        0        0        0
# Vietnam             16.0000  108.0000        0        2        2        2
# West Bank and Gaza  31.9522   35.2332        0        0        0        0
# Zambia             -15.4167   28.2833        0        0        0        0
# Zimbabwe           -20.0000   30.0000        0        0        0        0
#
# ...

# %%
covid19_confirmed.drop(columns=['Lat','Long','Province/State'], inplace=True)

# %%
covid19_confirmed.sample(10)
# Out:
#              Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 52                    China        1        5       10       18       35
# 91                  Czechia        0        0        0        0        0
# 236             Timor-Leste        0        0        0        0        0
# 20               Bangladesh        0        0        0        0        0
# 202               Sri Lanka        0        0        0        0        0
# 84         Congo (Kinshasa)        0        0        0        0        0
# 235                   Syria        0        0        0        0        0
# 27   Bosnia and Herzegovina        0        0        0        0        0
# 106                 Finland        0        0        0        0        0
# 229                  Zambia        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  3/20/20  3/21/20  3/22/20  \
# 52        59       80       84      101  ...      299      303      313
# ...

# %%
covid19_confirmed.groupby(['Country/Region']).sum()
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# Venezuela                 0        0        0        0        0        0
# Vietnam                   0        2        2        2        2        2
# West Bank and Gaza        0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
covid19_confirmed_country = covid19_confirmed.groupby(['Country/Region']).sum()

# %%
covid19_confirmed_country.sample(10)
# Out:
#                           1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Haiti                           0        0        0        0        0
# Argentina                       0        0        0        0        0
# Canada                          0        0        0        0        1
# Andorra                         0        0        0        0        0
# Central African Republic        0        0        0        0        0
# El Salvador                     0        0        0        0        0
# Lithuania                       0        0        0        0        0
# Gabon                           0        0        0        0        0
# Montenegro                      0        0        0        0        0
# Lebanon                         0        0        0        0        0
#
#                           1/27/20  1/28/20  1/29/20  1/30/20  1/31/20  ...  \
# Country/Region                                                         ...
# ...

# %%
covid19_confirmed_country.loc['US']
# Out:
# 1/22/20         1
# 1/23/20         1
# 1/24/20         2
# 1/25/20         2
# 1/26/20         5
#             ...
# 3/25/20     65778
# 3/26/20     83836
# 3/27/20    101657
# 3/28/20    121478
# 3/29/20    140886
# Name: US, Length: 68, dtype: int64

# %%
covid19_confirmed_countryT = covid19_confirmed_country.T

# %%
covid19_confirmed_countryT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68 entries, 1/22/20 to 3/29/20
# Columns: 177 entries, Afghanistan to Zimbabwe
# dtypes: int64(177)
# memory usage: 97.1+ KB

# %%
covid19_confirmed_country.loc[['US','China']]
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# US                    1        1        2        2        5        5        5
# China               548      643      920     1406     2075     2877     5509
#
#                 1/29/20  1/30/20  1/31/20  ...  3/20/20  3/21/20  3/22/20  \
# Country/Region                             ...
# US                    5        5        7  ...    19100    25489    33276
# China              6087     8141     9802  ...    81250    81305    81435
#
#                 3/23/20  3/24/20  3/25/20  3/26/20  3/27/20  3/28/20  3/29/20
# Country/Region
# US                43847    53740    65778    83836   101657   121478   140886
# China             81498    81591    81661    81782    81897    81999    82122
#
# [2 rows x 68 columns]

# %%
current_status = covid19_confirmed_countryT.loc['3/29/20']

# %%
top10_infected = current_status.sort_values(ascending=False)[:10]

# %%
import matplotlib.pyplot as plt

# %%
top10_infected.plot.bar()

# %%
us_confirmed_cases = covid19_confirmed_country.loc['US']

# %%
us_confirmed_cases.plot()

# %%
covid19_confirmed_country.loc[['US','Italy','China']]
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# US                    1        1        2        2        5        5        5
# Italy                 0        0        0        0        0        0        0
# China               548      643      920     1406     2075     2877     5509
#
#                 1/29/20  1/30/20  1/31/20  ...  3/20/20  3/21/20  3/22/20  \
# Country/Region                             ...
# US                    5        5        7  ...    19100    25489    33276
# Italy                 0        0        2  ...    47021    53578    59138
# China              6087     8141     9802  ...    81250    81305    81435
#
#                 3/23/20  3/24/20  3/25/20  3/26/20  3/27/20  3/28/20  3/29/20
# Country/Region
# US                43847    53740    65778    83836   101657   121478   140886
# Italy             63927    69176    74386    80589    86498    92472    97689
# ...

# %%
covid19_confirmed_country.loc[['US','Italy','China']].T.plot()

# %%
covid19_death = pd.read_csv('./../data/time_series_covid19_deaths_global.csv')

# %%
covid19_death.sample(10)
# Out:
#        Province/State    Country/Region      Lat      Long  1/22/20  1/23/20  \
# 35            Alberta            Canada  53.9333 -116.5765        0        0
# 181               NaN              Peru  -9.1900  -75.0152        0        0
# 193               NaN           Senegal  14.4974  -14.4524        0        0
# 57             Hainan             China  19.1959  109.7453        0        0
# 231  Diamond Princess            Canada   0.0000    0.0000        0        0
# 192               NaN      Saudi Arabia  24.0000   45.0000        0        0
# 110           Mayotte            France -12.8275   45.1662        0        0
# 184               NaN          Portugal  39.3999   -8.2245        0        0
# 60              Henan             China  33.8820  113.6140        0        0
# 84                NaN  Congo (Kinshasa)  -4.0383   21.7587        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/20/20  3/21/20  3/22/20  \
# ...

# %%
covid19_death.drop(columns=['Lat','Long','Province/State'], inplace=True)

# %%
covid19_death.sample(10)
# Out:
#     Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 189    Saint Lucia        0        0        0        0        0        0
# 213         Turkey        0        0        0        0        0        0
# 72           China        0        0        0        0        0        0
# 101        Eritrea        0        0        0        0        0        0
# 95        Djibouti        0        0        0        0        0        0
# 11       Australia        0        0        0        0        0        0
# 13       Australia        0        0        0        0        0        0
# 214         Uganda        0        0        0        0        0        0
# 0      Afghanistan        0        0        0        0        0        0
# 42          Canada        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/20/20  3/21/20  3/22/20  3/23/20  \
# 189        0        0        0  ...        0        0        0        0
# ...

# %%
covid19_death_country = covid19_death.groupby(['Country/Region']).sum()

# %%
covid19_death_country.loc['US']
# Out:
# 1/22/20       0
# 1/23/20       0
# 1/24/20       0
# 1/25/20       0
# 1/26/20       0
#            ...
# 3/25/20     942
# 3/26/20    1209
# 3/27/20    1581
# 3/28/20    2026
# 3/29/20    2467
# Name: US, Length: 68, dtype: int64

# %%
df = pd.concat([covid19_death_country.loc['US'], covid19_confirmed_country.loc['US']], axis=1)

# %%
df.sample(5)
# Out:
#          US  US
# 1/30/20   0   5
# 2/17/20   0  13
# 2/20/20   0  13
# 1/22/20   0   1
# 2/29/20   1  68

# %%
df.plot()

# %%
pd.concat([covid19_death_country.loc['China'], covid19_confirmed_country.loc['China']], axis=1).plot()

# %%
pd.concat([covid19_death_country.loc['Italy'], covid19_confirmed_country.loc['Italy']], axis=1).plot()
